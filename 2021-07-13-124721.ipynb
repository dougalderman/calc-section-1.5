# %%
plot(1.6*x^3-2.3*x-3.7, x, -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
derivative(1.6*x^3-2.3*x-3.7)
# Out:
# 4.80000000000000*x^2 - 2.30000000000000

# %%
eq=4.8*x^2 - 2.3

# %%
eq.find_root(-2,0)
# Out:
# -0.6922186552431729

# %%
eq.find_root(0,2)
# Out:
# 0.6922186552431729

# %%
plot(x^4-3*x^2+1, x, -5, 5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
derivative(x^4-3*x^2+1, x)
# Out:
# 4*x^3 - 6*x

# %%
plot(4*x^3 - 6*x, x, -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
4*1^3 - 6*1
# Out:
# -2

# %%
eq2 = (5*x^2 + 8*x - 3)/(3*x^2 + 2)

# %%
plot(eq2, x, -4, 4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq2_d=derivative(eq2, x)

# %%
eq2_d
# Out:
# 2*(5*x + 4)/(3*x^2 + 2) - 6*(5*x^2 + 8*x - 3)*x/(3*x^2 + 2)^2

# %%
plot(eq2_d, x, -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def f_eq2(x):
   return 2*(5*x + 4)/(3*x^2 + 2) - 6*(5*x^2 + 8*x - 3)*x/(3*x^2 + 2)^2

# %%
f_eq2(1)
# Out:
# 6/5
